# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['mse','mae','friedman_mse'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# ...

# %%
#re=grid.cv_results_
#grid_predictions=grid.predict(X_test)
#print("The RScore value for best parameters {}".format(grid.best_params_))
# Out:
# The RScore value for best parameters {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The RScore value for best parameters {}".format(grid.best_params_),r_score)
# Out:
# The RScore value for best parameters {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'} 0.5873988536704273

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001600      0.003200         0.000000        0.000000
# 1        0.001618      0.003237         0.000000        0.000000
# 2        0.000000      0.000000         0.000000        0.000000
# 3        0.003127      0.006253         0.000000        0.000000
# 4        0.003125      0.006250         0.000000        0.000000
# 5        0.003126      0.006251         0.000000        0.000000
# 6        0.002171      0.004341         0.000000        0.000000
# 7        0.000448      0.000896         0.000000        0.000000
# 8        0.001643      0.003215         0.000000        0.000000
# 9        0.001650      0.003299         0.000000        0.000000
# 10       0.000000      0.000000         0.000000        0.000000
# 11       0.003133      0.006266         0.000000        0.000000
# 12       0.000000      0.000000         0.000000        0.000000
# ...

# %%
age_input=float(input('Age:'))
bmi_input=float(input('BMI:'))
children_input=float(input('Children:'))
sex_male_input=int(input('Sex Male 0 or 1:'))
smoker_yes_input=int(input('Smoker yes 0 or 1:'))
# Out:
# Age:19
# BMI:27.900
# Children:0
# Sex Male 0 or 1:0
# Smoker yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Future_Prediction={}'.format(Future_Prediction))
# Out:
# Future_Prediction=[63770.42801]
